# %%
F.<r> = GF(31)[]
K.<i> = GF(31**2, name='i', modulus=r^2+1 )
R_2.<f>  = K[]
Y.<e_1,e_2,e_3> = K[] 
V = FractionField(Y) 
R_1.<x>  = V[]
a = GF(31)(2)
b = GF(31)(3)
x_2 = (x^4 + (-2*a)*x^2 + (-8*b)*x + a^2)/(4*x^3 + 4*a*x + 4*b)
n=4
h = x^3-e_1*x^2+e_2*x-e_3
D = (R_2(f^3+a*f+b)).roots()
for j in range(3):
    e = (D[j])[0];
    h_1 = (h((e*x+2*e^2+a)/(x-e))).numerator();
    h_1 = h_1/(h_1[2^(n-2)-1]);
    D_1 = (R_2(f^2-2*e*f-2*e^2-a)).roots();
    for k in range(2):
        u_0 = (D_1[k])[0];
        h_3 = h_1*h
        denom1 = (x-e)*(x-u_0)^2*(h_3)^2 ;
        g = 2^n*x-(-denom1[2^n-2])-(3*x^2+a)*(denom1.derivative(x))/denom1-2*(x^3+a*x+b)*(((denom1.derivative(x))/denom1).derivative(x))
        g = (g.derivative(x)).numerator()
        r_1 = (x-u_0)*h_3
        r_1 = (r_1(x_2)).numerator()
        m = r_1.degree()
        r_1 = r_1/(r_1[m]);
        r_1, r_2 = r_1.quo_rem(h_3)
        r_1 = (x+u_0-2*e)*r_1
        g = g-r_1
        I = Y.ideal(0)
        print 'for e='+format(e)+' and u_0='+format(u_0)  
        for l in range(3*(2^(n-1)-1)+2):
            I = I + (Y(((g.polynomial(x))[l]).numerator()))*Y
         
        print  I.variety()
# Out:
# for e=30 and u_0=24
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ac9a2649189f> in <module>()
#      34             I = I + (Y(((g.polynomial(x))[l]).numerator()))*Y
#      35
# ---> 36         print  I.variety()
#
# /opt/sagemath-8.7/local/lib/python2.7/site-packages/sage/rings/polynomial/multi_polynomial_ideal.pyc in __call__(self, *args, **kwds)
#     295         if not R.base_ring().is_field():
#     296             raise ValueError("Coefficient ring must be a field for function '%s'."%(self.f.__name__))
# --> 297         return self.f(self._instance, *args, **kwds)
#     298
#     299 require_field = RequireField
#
# /opt/sagemath-8.7/local/lib/python2.7/site-packages/sage/rings/polynomial/multi_polynomial_ideal.pyc in variety(self, ring)
#    2400         d = self.dimension()
#    2401         if d > 0:
# ...

# %%
print I
# Out:
# Ideal (0, 15*e_1^44 - 11*e_1^43*e_2 - 7*e_1^42*e_2^2 + 5*e_1^41*e_2^3 - 15*e_1^40*e_2^4 + 8*e_1^39*e_2^5 + 2*e_1^38*e_2^6 + 9*e_1^37*e_2^7 + 13*e_1^36*e_2^8 + 3*e_1^35*e_2^9 + 7*e_1^34*e_2^10 + 2*e_1^33*e_2^11 + 7*e_1^32*e_2^12 + 3*e_1^31*e_2^13 + 13*e_1^30*e_2^14 + 9*e_1^29*e_2^15 + 2*e_1^28*e_2^16 + 8*e_1^27*e_2^17 - 15*e_1^26*e_2^18 + 5*e_1^25*e_2^19 - 7*e_1^24*e_2^20 - 11*e_1^23*e_2^21 + 15*e_1^22*e_2^22 - 11*e_1^43*e_3 - 14*e_1^42*e_2*e_3 + 15*e_1^41*e_2^2*e_3 + 2*e_1^40*e_2^3*e_3 + 9*e_1^39*e_2^4*e_3 + 12*e_1^38*e_2^5*e_3 + e_1^37*e_2^6*e_3 + 11*e_1^36*e_2^7*e_3 - 4*e_1^35*e_2^8*e_3 + 8*e_1^34*e_2^9*e_3 - 9*e_1^33*e_2^10*e_3 - 9*e_1^32*e_2^11*e_3 + 8*e_1^31*e_2^12*e_3 - 4*e_1^30*e_2^13*e_3 + 11*e_1^29*e_2^14*e_3 + e_1^28*e_2^15*e_3 + 12*e_1^27*e_2^16*e_3 + 9*e_1^26*e_2^17*e_3 + 2*e_1^25*e_2^18*e_3 + 15*e_1^24*e_2^19*e_3 - 14*e_1^23*e_2^20*e_3 - 11*e_1^22*e_2^21*e_3 - 7*e_1^42*e_3^2 + 15*e_1^41*e_2*e_3^2 + 3*e_1^40*e_2^2*e_3^2 - 13*e_1^39*e_2^3*e_3^2 - e_1^38*e_2^4*e_3^2 + 3*e_1
# ...

# %%
F.<r> = GF(31)[]
K.<i> = GF(31**2, name='i', modulus=r^2+1 )
R_2.<f>  = K[]
Y.<e_1,e_2> = K[] 
V = FractionField(Y) 
R_1.<x>  = V[]
a = GF(31)(2)
b = GF(31)(3)
x_2 = (x^4 + (-2*a)*x^2 + (-8*b)*x + a^2)/(4*x^3 + 4*a*x + 4*b)
n = 3
h = x^2-e_1*x+e_2
D = (R_2(f^3+a*f+b)).roots()
for j in range(3):
    e = (D[j])[0];
    D_1 = (R_2(f^2-2*e*f-2*e^2-a)).roots();
    for k in range(2):
        u_0 = (D_1[k])[0];
        denom1 = (x-e)*(x-u_0)^2*(h)^2 ;
        g = 2^n*x-(-denom1[2^n-2])-(3*x^2+a)*(denom1.derivative(x))/denom1-2*(x^3+a*x+b)*(((denom1.derivative(x))/denom1).derivative(x))
        g = (g.derivative(x)).numerator()
        r_1 = (x-u_0)*h
        r_1 = (r_1(x_2)).numerator()
        m = r_1.degree()
        r_1 = r_1/(r_1[m]);
        r_1, r_2 = r_1.quo_rem(h)
        r_1 = (x+u_0-2*e)*r_1
        g = g-r_1
        I = Y.ideal(0)
        print 'for e='+format(e)+' and u_0='+format(u_0)  
        for l in range(3*(2^(n-1)-1)+2):
            I = I + (Y(((g.polynomial(x))[l]).numerator()))*Y
         
        print  I.variety()
# Out:
# for e=30 and u_0=24
# [{e_1: 26, e_2: 9}, {e_1: 8, e_2: 27}]
# for e=30 and u_0=5
# [{e_1: 30*i + 10, e_2: i + 25}, {e_1: i + 10, e_2: 30*i + 25}]
# for e=22 and u_0=11
# [{e_1: 13*i + 22, e_2: 7*i + 28}, {e_1: 18*i + 22, e_2: 24*i + 28}]
# for e=22 and u_0=2
# [{e_1: 24, e_2: 10}, {e_1: 15, e_2: 29}]
# for e=10 and u_0=16*i + 10
# [{e_1: 4*i + 30, e_2: 9*i + 6}, {e_1: 29*i + 10, e_2: 11*i + 23}]
# for e=10 and u_0=15*i + 10
# [{e_1: 2*i + 10, e_2: 20*i + 23}, {e_1: 27*i + 30, e_2: 22*i + 6}]

# %%
F.<r> = GF(31)[]
K.<i> = GF(31**2, name='i', modulus=r^2+1 )
R_2.<f>  = K[]
Y.<e_1,e_2,e_3,e_4,e_5,e_6> = K[] 
V = FractionField(Y) 
R_1.<x>  = V[]
a = GF(31)(2)
b = GF(31)(3)
x_2 = (x^4 + (-2*a)*x^2 + (-8*b)*x + a^2)/(4*x^3 + 4*a*x + 4*b)
n = 4
h = x^6-e_1*x^5+e_2*x^4-e_3*x^3+e_4*x^2-e_5*x+e_6
D = (R_2(f^3+a*f+b)).roots()
for j in range(3):
    e = (D[j])[0];
    D_1 = (R_2(f^2-2*e*f-2*e^2-a)).roots();
    for k in range(2):
        u_0 = (D_1[k])[0];
        denom1 = (x-e)*(x-u_0)^2*(h)^2 ;
        g = 2^n*x-(-denom1[2^n-2])-(3*x^2+a)*(denom1.derivative(x))/denom1-2*(x^3+a*x+b)*(((denom1.derivative(x))/denom1).derivative(x))
        g = (g.derivative(x)).numerator()
        r_1 = (x-u_0)*h
        r_1 = (r_1(x_2)).numerator()
        m = r_1.degree()
        r_1 = r_1/(r_1[m]);
        r_1, r_2 = r_1.quo_rem(h)
        r_1 = (x+u_0-2*e)*r_1
        g = g-r_1
        I = Y.ideal(0)
        print 'for e='+format(e)+' and u_0='+format(u_0)  
        for l in range(3*(2^(n-1)-1)+2):
            I = I + (Y(((g.polynomial(x))[l]).numerator()))*Y
         
        print  I.variety()
# Out:
# for e=30 and u_0=24
# [{e_1: 7, e_2: 3, e_3: 18, e_4: 15, e_5: 2, e_6: 17}, {e_1: 26*i + 24, e_2: 4*i + 25, e_3: 26*i + 10, e_4: 29*i + 24, e_5: 27*i + 12, e_6: 12*i + 29}, {e_1: 5*i + 24, e_2: 27*i + 25, e_3: 5*i + 10, e_4: 2*i + 24, e_5: 4*i + 12, e_6: 19*i + 29}, {e_1: 25, e_2: 15, e_3: 29, e_4: 23, e_5: 17, e_6: 15}]
# for e=30 and u_0=5
# [{e_1: 22*i + 10, e_2: 4*i + 17, e_3: 14*i + 14, e_4: 5*i + 27, e_5: 25, e_6: 17*i}, {e_1: 9*i + 10, e_2: 27*i + 17, e_3: 17*i + 14, e_4: 26*i + 27, e_5: 25, e_6: 14*i}, {e_1: 3*i + 19, e_2: 6*i + 14, e_3: 14*i + 9, e_4: 28*i + 25, e_5: 19, e_6: 11*i + 7}, {e_1: 28*i + 19, e_2: 25*i + 14, e_3: 17*i + 9, e_4: 3*i + 25, e_5: 19, e_6: 20*i + 7}]
# for e=22 and u_0=11
# ...

# %%
F.<r> = GF(31)[]
K.<i> = GF(31**2, name='i', modulus=r^2+1 )
R_2.<f>  = K[]
Y.<e_1,e_2,e_3,e_4,e_5,e_6,e_7,e_8,e_9,e_10,e_11,e_12,e_13,e_14> = K[] 
V = FractionField(Y) 
R_1.<x>  = V[]
a = GF(31)(2)
b = GF(31)(3)
x_2 = (x^4 + (-2*a)*x^2 + (-8*b)*x + a^2)/(4*x^3 + 4*a*x + 4*b)
n = 5
h = x^(14)-e_1*x^(13)+e_2*x^(12)-e_3*x^(11)+e_4*x^(10)-e_5*x^(9)+e_6*x^(8)-e_7*x^(7)+e_8*x^(6)-e_9*x^(5)+e_10*x^(4)-e_11*x^(3)+e_12*x^(2)-e_13*x+e_14
D = (R_2(f^3+a*f+b)).roots()
for j in range(3):
    e = (D[j])[0];
    D_1 = (R_2(f^2-2*e*f-2*e^2-a)).roots();
    for k in range(2):
        u_0 = (D_1[k])[0];
        denom1 = (x-e)*(x-u_0)^2*(h)^2 ;
        g = 2^n*x-(-denom1[2^n-2])-(3*x^2+a)*(denom1.derivative(x))/denom1-2*(x^3+a*x+b)*(((denom1.derivative(x))/denom1).derivative(x))
        g = (g.derivative(x)).numerator()
        r_1 = (x-u_0)*h
        r_1 = (r_1(x_2)).numerator()
        m = r_1.degree()
        r_1 = r_1/(r_1[m]);
        r_1, r_2 = r_1.quo_rem(h)
        r_1 = (x+u_0-2*e)*r_1
        g = g-r_1
        I = Y.ideal(0)
        print 'for e='+format(e)+' and u_0='+format(u_0)  
        for l in range(3*(2^(n-1)-1)+2):
            I = I + (Y(((g.polynomial(x))[l]).numerator()))*Y
         
        print  I.variety()
# Out:
# for e=30 and u_0=24
